# %%
# !pip install sqlalchemy psycopg2-binary pandas
# Out:
# Requirement already satisfied: sqlalchemy in c:\users\prajw\anaconda3\lib\site-packages (2.0.30)
# Collecting psycopg2-binary
#   Downloading psycopg2_binary-2.9.11-cp312-cp312-win_amd64.whl.metadata (5.1 kB)
# Requirement already satisfied: pandas in c:\users\prajw\anaconda3\lib\site-packages (2.3.3)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\prajw\anaconda3\lib\site-packages (from sqlalchemy) (4.15.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\prajw\anaconda3\lib\site-packages (from sqlalchemy) (3.0.1)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\prajw\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\prajw\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\prajw\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\prajw\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\prajw\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading psycopg2_binary-2.9.11-cp312-cp312-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.7 MB 330.3 kB/s eta 0:00:09
#     --------------------------------------- 0.1/2.7 MB 550.5 kB/s eta 0:00:05
#    - -------------------------------------- 0.1/2.7 MB 563.7 kB/s eta 0:00:05
#    --- ------------------------------------ 0.2/2.7 MB 1.1 MB/s eta 0:00:03
#    ------- -------------------------------- 0.5/2.7 MB 2.0 MB/s eta 0:00:02
#    -------- ------------------------------- 0.6/2.7 MB 2.0 MB/s eta 0:00:02
#    ---------------------------- ----------- 2.0/2.7 MB 5.7 MB/s eta 0:00:01
#    ---------------------------------------  2.7/2.7 MB 7.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 6.9 MB/s eta 0:00:00
# Installing collected packages: psycopg2-binary
# Successfully installed psycopg2-binary-2.9.11

# %%
from sqlalchemy import create_engine
import pandas as pd

CONN_STR = 'postgresql://postgres:0000@localhost:5432/bibadb'
engine = create_engine(CONN_STR)
print("connection success")
# Out:
# connection success

# %%
import os

# %%
directory = './'

for filename in os.listdir(directory):
    if filename.endswith('.csv'):
        table_name = filename.replace('.csv', '').lower()
        file_path = os.path.join(directory,filename)
        print(f"Uploading {filename} to table {table_name} ..")
        df = pd.read_csv(file_path)
        df.to_sql(table_name, engine, if_exists='replace',index='false')
        print(f"Successfully uploaded data to Postgres Database table --> {table_name}")
# Out:
# Uploading clean_data.csv to table clean_data ..
# Successfully uploaded data to Postgres Database table --> clean_data
# Uploading final_campaign_list.csv to table final_campaign_list ..
# Successfully uploaded data to Postgres Database table --> final_campaign_list
# Uploading olist_customers_dataset.csv to table olist_customers_dataset ..
# Successfully uploaded data to Postgres Database table --> olist_customers_dataset
# Uploading olist_geolocation_dataset.csv to table olist_geolocation_dataset ..
# Successfully uploaded data to Postgres Database table --> olist_geolocation_dataset
# Uploading olist_orders_dataset.csv to table olist_orders_dataset ..
# Successfully uploaded data to Postgres Database table --> olist_orders_dataset
# Uploading olist_order_items_dataset.csv to table olist_order_items_dataset ..
# Successfully uploaded data to Postgres Database table --> olist_order_items_dataset
# Uploading olist_order_payments_dataset.csv to table olist_order_payments_dataset ..
# Successfully uploaded data to Postgres Database table --> olist_order_payments_dataset
# Uploading olist_order_reviews_dataset.csv to table olist_order_reviews_dataset ..
# Successfully uploaded data to Postgres Database table --> olist_order_reviews_dataset
# Uploading olist_products_dataset.csv to table olist_products_dataset ..
# Successfully uploaded data to Postgres Database table --> olist_products_dataset
# Uploading olist_sellers_dataset.csv to table olist_sellers_dataset ..
# Successfully uploaded data to Postgres Database table --> olist_sellers_dataset
# Uploading product_category_name_translation.csv to table product_category_name_translation ..
# Successfully uploaded data to Postgres Database table --> product_category_name_translation
# Uploading rfm_table.csv to table rfm_table ..
# Successfully uploaded data to Postgres Database table --> rfm_table
# Uploading rfm_with_clusters.csv to table rfm_with_clusters ..
# Successfully uploaded data to Postgres Database table --> rfm_with_clusters

# %%
# !pip install sqlalchemy psycopg2-binary pandas
# Out:
# Requirement already satisfied: sqlalchemy in C:\Users\Tushar Puntambekar\AppData\Local\Programs\Python\Python313\Lib\site-packages (2.0.44)
# Requirement already satisfied: psycopg2-binary in C:\Users\Tushar Puntambekar\AppData\Local\Programs\Python\Python313\Lib\site-packages (2.9.11)
# Requirement already satisfied: pandas in C:\Users\Tushar Puntambekar\AppData\Local\Programs\Python\Python313\Lib\site-packages (2.3.2)
# Requirement already satisfied: greenlet>=1 in C:\Users\Tushar Puntambekar\AppData\Local\Programs\Python\Python313\Lib\site-packages (from sqlalchemy) (3.2.4)
# Requirement already satisfied: typing-extensions>=4.6.0 in C:\Users\Tushar Puntambekar\AppData\Local\Programs\Python\Python313\Lib\site-packages (from sqlalchemy) (4.15.0)
# Requirement already satisfied: numpy>=1.26.0 in C:\Users\Tushar Puntambekar\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas) (2.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\Tushar Puntambekar\AppData\Roaming\Python\Python313\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\Tushar Puntambekar\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\Tushar Puntambekar\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in C:\Users\Tushar Puntambekar\AppData\Roaming\Python\Python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
from sqlalchemy import create_engine
import pandas as pd
import os

engine = create_engine('postgresql://postgres:8899@localhost:5433/biba')
print("Connection Success")
# Out:
# Connection Success

# %%
directory = "../data/processed"

for filename in os.listdir(directory):
    if filename.endswith('.csv'):
        table_name= filename.replace('.csv', "").lower()
        file_path = os.path.join(directory,filename)
        print(f"uploading {filename} to {table_name}")

        df = pd.read_csv(file_path)
        df.to_sql(table_name, engine, if_exists='replace',index='false')
        print("Successfully Uploaded the final data with RMF to Postgre database")

print("Done")
# Out:
# uploading clean_data.csv to clean_data
# Successfully Uploaded the final data with RMF to Postgre database
# uploading final_campaign_list.csv to final_campaign_list
# Successfully Uploaded the final data with RMF to Postgre database
# uploading rfm_table.csv to rfm_table
# Successfully Uploaded the final data with RMF to Postgre database
# uploading rfm_with_clusters.csv to rfm_with_clusters
# Successfully Uploaded the final data with RMF to Postgre database
# Done
